# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/coursea_data.csv')

# %%
df
# Out:
#      Unnamed: 0                                       course_title  \
# 0           134  (ISC)² Systems Security Certified Practitioner...
# 1           743  A Crash Course in Causality:  Inferring Causal...
# 2           874                     A Crash Course in Data Science
# 3           413                            A Law Student's Toolkit
# 4           635                A Life of Happiness and Fulfillment
# ..          ...                                                ...
# 886         236                         Программирование на Python
# 887         883               Психолингвистика (Psycholinguistics)
# 888         545       Разработка интерфейсов: вёрстка и JavaScript
# 889         875                            Русский как иностранный
# 890         163      Финансовые инструменты для частного инвестора
#
#                                    course_organization  \
# 0                                               (ISC)²
# ...

# %%
target=df['course_difficulty']

# %%
tft = target.head(10)
tft
# Out:
# 0        Beginner
# 1    Intermediate
# 2           Mixed
# 3           Mixed
# 4           Mixed
# 5        Beginner
# 6        Beginner
# 7    Intermediate
# 8        Beginner
# 9    Intermediate
# Name: course_difficulty, dtype: object

# %%
feature = df.drop('course_difficulty',axis=1)

# %%
tff = feature.head(10)
tff
# Out:
#    Unnamed: 0                                       course_title  \
# 0         134  (ISC)² Systems Security Certified Practitioner...
# 1         743  A Crash Course in Causality:  Inferring Causal...
# 2         874                     A Crash Course in Data Science
# 3         413                            A Law Student's Toolkit
# 4         635                A Life of Happiness and Fulfillment
# 5         661  ADHD: Everyday Strategies for Elementary Students
# 6          54                                    AI For Everyone
# 7         488                           AI For Medical Treatment
# 8          58                        AI Foundations for Everyone
# 9         129                           AI for Medical Diagnosis
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# ...

# %%
#using seaborn and matplotlib using bar graph
plt.xlabel('course_difficulty')
sns.countplot(tft)
# Out:
# <Axes: xlabel='course_difficulty', ylabel='course_difficulty'>

# %%
# using matplotlib to make histogram
plt.xlabel('course_difficulty')
plt.hist(tft)
# Out:
# (array([4., 0., 0., 0., 0., 3., 0., 0., 0., 3.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel('course_students_enrolled')
plt.ylabel('course_difficulty')
plt.plot(tff['course_students_enrolled'],tft)

# %%
plt.xlabel('course_students_enrolled')
plt.ylabel('course_difficulty')
plt.bar(tff['course_students_enrolled'],tft)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.xlabel('course_students_enrolled')
plt.ylabel('course_difficulty')
plt.scatter(tff['course_students_enrolled'],tft)

# %%
plt.xlabel('course_students_enrolled')
sns.countplot(tff['course_Certificate_type'])
# Out:
# <Axes: xlabel='course_students_enrolled', ylabel='course_Certificate_type'>

# %%
plt.xlabel('course_students_enrolled')
sns.countplot(tft)
# Out:
# <Axes: xlabel='course_students_enrolled', ylabel='course_difficulty'>

# %%
plt.ylabel('course_title')
plt.scatter(tft,tff['course_title'])

# %%
plt.ylabel('course_organization')
plt.scatter(tft,tff['course_organization'])

# %%
begcourse = df[df['course_difficulty']=='Beginner']
begcourse
# Out:
#      Unnamed: 0                                       course_title  \
# 0           134  (ISC)² Systems Security Certified Practitioner...
# 5           661  ADHD: Everyday Strategies for Elementary Students
# 6            54                                    AI For Everyone
# 8            58                        AI Foundations for Everyone
# 12           43                                   AWS Fundamentals
# ..          ...                                                ...
# 877         492                          Искусство ведения бизнеса
# 879         722         Корпоративные финансы и стоимость компании
# 880         811             Математика и Python для анализа данных
# 883         703                  Основы программирования на Python
# 890         163      Финансовые инструменты для частного инвестора
#
#                                    course_organization  \
# 0                                               (ISC)²
# ...

# %%
intermediatecourse = df[df['course_difficulty']=='Intermediate']
intermediatecourse
# Out:
#      Unnamed: 0                                       course_title  \
# 1           743  A Crash Course in Causality:  Inferring Causal...
# 7           488                           AI For Medical Treatment
# 9           129                           AI for Medical Diagnosis
# 10          283                           AI for Medical Prognosis
# 11           35                                    AI for Medicine
# ..          ...                                                ...
# 884         841               Основы разработки на C++: белый пояс
# 885         889                                Погружение в Python
# 886         236                         Программирование на Python
# 888         545       Разработка интерфейсов: вёрстка и JavaScript
# 889         875                            Русский как иностранный
#
#                             course_organization course_Certificate_type  \
# 1                    University of Pennsylvania                  COURSE
# ...

# %%
mixcourse = df[df['course_difficulty']=='Mixed']
mixcourse
# Out:
#      Unnamed: 0                                       course_title  \
# 2           874                     A Crash Course in Data Science
# 3           413                            A Law Student's Toolkit
# 4           635                A Life of Happiness and Fulfillment
# 17          819                Aboriginal Worldviews and Education
# 21          604                               Accounting Analytics
# ..          ...                                                ...
# 863         543                                What is Compliance?
# 865         379                                    What is Social?
# 869         213               Write Professional Emails in English
# 872         359  e-Learning Ecologies: Innovative Approaches to...
# 887         883               Психолингвистика (Psycholinguistics)
#
#                             course_organization course_Certificate_type  \
# 2                      Johns Hopkins University                  COURSE
# ...

# %%
title = tff['course_title']
rating = tff['course_rating']
plt.xlabel('course_rating')
plt.ylabel('course_title')
plt.scatter(rating,title)

# %%
title = tff['course_organization']
rating = tff['course_rating']
plt.xlabel('course_rating')
plt.ylabel('course_organization')
plt.scatter(rating,title)

# %%
title = tft
rating = tff['course_rating']
plt.xlabel('course_rating')
plt.ylabel('course_difficulty')
plt.scatter(rating,title)
